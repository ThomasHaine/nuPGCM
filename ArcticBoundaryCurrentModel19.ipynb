# %% [markdown]
# # Development of Arctic boundary current model
#
# See `gridap_development/ArcticBoundaryCurrentModel12.ipynb` for development of NS solver using `gridap`. This version switches to `nuPGCM`.
#
# 13.  `ArcticBoundaryCurrentModel13.ipynb`: Migrate to [`nuPGCM`](https://github.com/hgpeterson/nuPGCM) by merging `ArcticBoundaryCurrentModel12.ipynb` with `nuPGCM/examples.run.jl`.
# 14.  `ArcticBoundaryCurrentModel14.ipynb`: Switch to `ArcticBasin.msh` geometry.
# 15.  `ArcticBoundaryCurrentModel15.ipynb`: Make consistent with `examples/run.jl`.
# 16.  `ArcticBoundaryCurrentModel16.ipynb`: Adjust plotting. Experiment with different parameter settings.
# 17.  `ArcticBoundaryCurrentModel17.ipynb`: Add forcing from v0.4.0 and update from my customizations (0.3.0_custom).
# 18.  `ArcticBoundaryCurrentModel18.ipynb`: Add wind forcing.
# 19.  `ArcticBoundaryCurrentModel19.ipynb`: Add buoyancy forcing.
#
# Goals: Add T/S equation of state
#
# Run this notebook with `nuPGCM` branch `0.4.0_custom`
#
# twnh August, September '25

# %% [markdown]
# ## Problem statement
#
# Following Peterson & Callies (2025, in review at JPO, their (A1)–(A4), (13)), the (non-dimensional) equations we solve are:
# $$
# \text{Inversion: }
# \left\lbrace
# \begin{aligned}
# -v &= - \frac{\partial p}{\partial x} + \epsilon^2 \left( \alpha^2 \frac{\partial ^2 u}{\partial x^2} + \alpha^2 \frac{\partial ^2 u}{\partial y^2} + \frac{\partial ^2 u}{\partial z^2}\right), \\
# u &= - \frac{\partial p}{\partial y} + \epsilon^2 \left( \alpha^2 \frac{\partial ^2 v}{\partial x^2} + \alpha^2 \frac{\partial ^2 v}{\partial y^2} + \frac{\partial ^2 v}{\partial z^2}\right), \\
# \frac{\partial p}{\partial z} & = b + \epsilon^2 \alpha^2 \left( \alpha^2 \frac{\partial ^2 w}{\partial x^2} + \alpha^2 \frac{\partial ^2 w}{\partial y^2} + \frac{\partial ^2 w}{\partial z^2} \right) ,\\
# \nabla\cdot \boldsymbol{u} &= 0,
# \end{aligned}
# \right.
# $$
# $$
# \text{Buoyancy: }
# \mu \varrho \left( \frac{\partial b}{\partial t} + \boldsymbol{u} \cdot \nabla b \right) = \epsilon^2 \alpha^2 \left[ \frac{\partial}{\partial x} \left( \kappa(\boldsymbol{x}) \frac{\partial b}{\partial x}\right) + \frac{\partial}{\partial y} \left( \kappa (\boldsymbol{x}) \frac{\partial b}{\partial y}\right) + \frac{\partial}{\partial z} \left( \kappa(\boldsymbol{x}) \frac{\partial b}{\partial z}\right) \right]
# $$
# (see also Peterson & Callies, 2025, in prep. for JAMES, their (12)–(14)).
# Forcing is given by:
# $$
# \text{Boundary conditions: }\left\lbrace
# \begin{aligned}
# \boldsymbol{t} \cdot \boldsymbol{\sigma} \cdot \mathbf{n} = \tau_{\text{imposed}} (\boldsymbol{x}) &\text{ on } \Gamma_s, \\
# \boldsymbol{u} = \boldsymbol{0} &\text{ on } \Gamma_w . \\
# \end{aligned}
# \right.
# $$
# However, their solutions are unforced, and the `examples/run.jl` code has no forcing.
# The domain $\Omega$ rotates with constant Coriolis parameter and has boundary $\partial \Omega$, ${\mathbf n}$ is the unit outward normal, $\boldsymbol{t}$ is the tangential direction at the surface, $\Gamma_s$, and $\boldsymbol{\sigma} = \nabla u$ is the stress vector. The driving force is the tangential stress $\tau_{\text{imposed}}$ (units of $\text{m}^{2} \text{s}^{-2}$ ). The mean value of the pressure anomaly is constrained to equal zero,
# $$
# \int_\Omega p \ {\rm d}\Omega = 0 .
# $$
# The initial condition is no flow and $b_{tot} = b + N^2 z$, so that $b$ measures the anomaly from uniform stratification (see: `nuPGCM/src/model.jl` and this [issue](https://github.com/hgpeterson/nuPGCM/issues/5).)
#
# We're also interested in:
# 1. Two-component equation of state for buoyancy $b$.
# 2. Buoyancy forcing on $\Gamma_s$ and $\Gamma_w$.
# 3. Free-slip (no stress) boundary conditions on $\Gamma_w$ (but not for the stress-driven case, unless the integrated applied stress vanishes).

# %% [markdown]
# ### Non-dimensional parameters
#
# The scaling is as follows (Peterson & Callies, 2025, in review):
# $$
# \begin{align}
# x, y & \sim L, \nonumber \\
# z & \sim H_0, \nonumber \\
# u, v & \sim U_0, \nonumber \\
# w & \sim \frac{U_0 H_0}{L}, \nonumber \\
# f & \sim f_0, \nonumber \\
# \nu & \sim \nu_0, \nonumber \\
# \kappa & \sim \kappa_0 ,\nonumber \\
# p & \sim f_0 U_0 L, \text{ with units of Pa/(kgm$^{-3}$)}\nonumber \\
# b & \sim \frac{f_0 U_0 L}{H_0} = N^2 H_0  \implies U_0 = \frac{N^2 H_0^2}{f_0 L} , \nonumber \\
# t & \sim \frac{L}{U_0} , \nonumber \\
# \tau \text{ (units m}^2\text{s}^2\text{)} & \sim \frac{\nu_0 U_0}{H_0} , \nonumber
# \end{align}
# $$
# with non-dimensional numbers
# $$
# \begin{align}
# \text{Ekman number: } \epsilon & = \frac{\nu_0} {f_0 H_0^2} , \nonumber \\
# \text{Burger number: } \varrho & = \frac{N^2 H_0^2} {f_0^2 L^2} ,  \nonumber \\
# \text{Turbulent Prandtl number: } \mu & = \frac{\nu_0} {\kappa_0} ,  \nonumber \\
# \text{Aspect ratio: } \alpha & = \frac{H_0} {L}
# \end{align}
# $$
#
# The dimensional viscosity is a constant $\nu = \nu_0$, but the diffusivity varies in space, usually decaying away from the bottom $\kappa(z)$.

# %% [markdown]
# We specify:
# \begin{align}
# \text{Characteristic domain depth:  } & H_0, \nonumber\\
# \text{Characteristic domain width:  } & L, \nonumber\\
# \text{Coriolis parameter (uniform): } & f_0,\nonumber\\
# \text{Characteristic diffusivity:   } & \kappa_0, \nonumber\\
# \text{Characteristic viscosity (uniform): } & \nu_0, \nonumber\\
# \text{Characteristic buoyancy frequency: } & N,  \nonumber\\
# %\text{Characteristic surface stress:   } & \tau_0, \nonumber\\
# \text{Non-dimensional diffusivity function: } & \kappa (\boldsymbol{x}), \nonumber\\
# \text{Non-dimensional domain depth function: } & H (\boldsymbol{x}), \nonumber\\
# %\text{Non-dimensional surface stress function: } & \tau (\boldsymbol{x}), \nonumber\\
# \text{Initial non-dimensional buoyancy field: } & b_0 (\boldsymbol{x}), \nonumber\\
# \end{align}

# %% [markdown]
# #### Import packages

# %%
using nuPGCM
using JLD2
using LinearAlgebra
using Printf
using Revise
using PyPlot

# %% [markdown]
# #### Configure nuPGCM

# %%
set_out_dir!(joinpath(@__DIR__, ""))
arch = CPU()
force_build_inversion = true
force_build_evolution = true 
pygui(false)
plt.style.use(joinpath(@__DIR__, "plots.mplstyle"))
plt.close("all")
# Out:
# ┌ Info: Output directory set to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/nuPGCM.jl:31

# %% [markdown]
# #### Define physical parameters

# %%
# Realistic parameters
# L  = 1000.0e3   # (m) domain size
# H₀ = 1000.0     # (m) domain height
# f₀ = 2.0e-4     # (s⁻¹) Coriolis parameter
# ν₀ = 8.0e-2     # (m²/s) kinematic viscosity
# κ₀ = 8.0e-2     # (m²/s) kinematic diffusivity
# N² = (10*f₀)^2  # (s⁻²) buoyancy frequency squared

# Values consistent with examples/run.jl
L  = 1000.0e3               # (m) domain size
H₀ = L/2                    # (m) domain height
f₀ = 2.0e-4                 # (s⁻¹) Coriolis parameter
β  = 0.0                    # (m⁻¹s⁻¹) beta parameter. Set to zero for an f-plane. Non-zero values require a 3D mesh.
ν₀ = 0.1^2 * f₀ * H₀^2      # (m²/s) kinematic viscosity
κ₀ = ν₀                     # (m²/s) kinematic diffusivity
N² = (10*f₀)^2              # (s⁻²) buoyancy frequency squared

println("Domain horizontal size            : ", L, " m")
println("Domain vertical size              : ", H₀, " m")
println("Coriolis parameter                : ", f₀, " s⁻¹")
println("Beta parameter                    : ", β, " m⁻¹s⁻¹")
println("Kinematic viscosity               : ", ν₀, " m⁻²s⁻¹")
println("Kinematic diffusivity             : ", κ₀, " m⁻²s⁻¹")
println("Buoyancy frequency                : ", sqrt(N²), " s⁻¹\n")
# Out:
# Domain horizontal size            : 1.0e6 m
# Domain vertical size              : 500000.0 m
# Coriolis parameter                : 0.0002 s⁻¹
# Beta parameter                    : 0.0 m⁻¹s⁻¹
# Kinematic viscosity               : 500000.00000000006 m⁻²s⁻¹
# Kinematic diffusivity             : 500000.00000000006 m⁻²s⁻¹
# Buoyancy frequency                : 0.002 s⁻¹

# %% [markdown]
# #### Wind forcing parameters

# %%
windspeed = 0.0             # m/s, maximum wind speed at r = L
# windspeed = -700.0          # m/s, maximum wind speed at r = L
println("Maximum windspeed                 : ", windspeed, "ms⁻¹")
ρₒ = 1000.0  # (kg/m³) reference density
cᴰ = 2.5e-3  # dimensionless drag coefficient
ρₐ = 1.225   # (kg/m³) average density of air
function u₁₀(x_in,windspeed)
    x,y = x_in[1], x_in[2]
    r = sqrt(x^2 + y^2)
    θ = atan(y, x)
    radial_wind = windspeed * r
    u₁₀ = radial_wind * [ - sin(θ),  cos(θ), 0.0 ] # m s⁻¹
    return u₁₀
end
τ₀(x) = Vector((ρₐ / ρₒ) * cᴰ * u₁₀(x,windspeed) * norm(u₁₀(x,windspeed))) # m² s⁻²
τˣ(x) = τ₀(x)[1]/τₛ  # non-dimensional zonal wind stress
τʸ(x) = τ₀(x)[2]/τₛ  # non-dimensional meridional wind stress
uₛ = sqrt((ρₐ / ρₒ) * cᴰ) # m/s, friction velocity  
println("Friction velocity                 : ", uₛ, " ms⁻¹")
# U₀ = uₛ^2 * H₀ / ν₀   # (m/s) speed scale
# Out:
# Maximum windspeed                 : 0.0ms⁻¹
# Friction velocity                 : 0.00175 ms⁻¹

# %% [markdown]
# #### Buoyancy initial condition
#
# This, implicitly, defines the buoyancy boundary condition at the surface too.

# %%
ΔT = 100.0                              # K, surface temperature difference across the front
println("Surface temperature diff.         : ", ΔT, " K")
α  = 2.0e-4                             # K⁻¹, thermal expansion coefficient
g  = 9.81                               # m/s², gravitational acceleration
b⁺ =  g * α * (ΔT / 2.0) / (N² * H₀)    # (non-dim) surface buoyancy on the warm side of the front
b⁻ = -g * α * (ΔT / 2.0) / (N² * H₀)    # (non-dim) surface buoyancy on the cold side of the front
r₀ = 1 / 2.0                            # (non-dim) radius of the buoyancy front
Δr = 1 / 8.0                            # (non-dim) width of the buoyancy front
z₀ = 1 / 4.0                            # (non-dim) e-folding depth scale for buoyancy decay
function initial_b(x_in,b⁺,b⁻,r₀,Δr,z₀) # Function to set the initial buoyancy anomaly field, and hence the buoyancy boundary condition (Dirichlet bc)
    x, y, z = x_in[1], x_in[2], x_in[3]
    r = sqrt(x^2 + y^2)
    b = b⁻ + (b⁺ - b⁻) * 0.5 * (1.0 + tanh((r - r₀) / Δr))
    b = b * exp(z/z₀)  # make buoyancy decay exponentially with depth
    return b
end
b₀(x) = initial_b(x,b⁺,b⁻,r₀,Δr,z₀)     # surface buoyancy boundary condition
println("Surface buoyancy diff.            : ", b⁺ - b⁻, " m²s⁻²")
println("Buoyancy forcing scale            : ", N² * H₀, " m²s⁻²\n")
# U₀ = uₛ^2 * H₀ / ν₀   # (m/s) speed scale
# Out:
# Surface temperature diff.         : 100.0 K
# Surface buoyancy diff.            : 0.0981 m²s⁻²
# Buoyancy forcing scale            : 2.0 m²s⁻²

# %% [markdown]
# #### Compute and report non-dimensional parameters

# %%
U₀ = N² * H₀^2 / (f₀ * L)   # (m/s) speed scale
println("Speed scale                       : ", U₀, " ms⁻¹")
τₛ = ν₀ * U₀ / H₀         # m²/s², stress scale
println("Stress scale.                     : ", τₛ, " m²s⁻²")
println("Time scale                        : ", L/U₀, " s")
println("Pressure scale                    : ", f₀*U₀*L*ρₒ, " Pa")

Ekman_layer_depth = sqrt(2*ν₀ / f₀) # (m), Ekman layer depth
println("Ekman layer depth                 : ", Ekman_layer_depth, " m")
println("Non-dimensional Ekman layer depth : ", Ekman_layer_depth/H₀)

ε = sqrt(ν₀ / (f₀ * H₀^2))      # Ekman number
println("\nEkman number ε                    : ", ε)
ϱ = (N² * H₀^2) / (f₀^2 * L^2)  # Burger number
println("Burger number ϱ                   : ", ϱ)
μ = ν₀ / κ₀                     # Turbulent Prandtl number
println("Turbulent Prandtl number μ        : ", μ)
α = H₀ / L                      # Aspect ratio
println("Domain aspect ratio α             : ", α)
# Out:
# Speed scale                       : 5000.0 ms⁻¹
# Stress scale.                     : 5000.000000000001 m²s⁻²
# Time scale                        : 200.0 s
# Pressure scale                    : 1.0e9 Pa
# Ekman layer depth                 : 70710.67811865476 m
# Non-dimensional Ekman layer depth : 0.14142135623730953
#
# Ekman number ε                    : 0.1
# Burger number ϱ                   : 25.0
# Turbulent Prandtl number μ        : 1.0
# Domain aspect ratio α             : 0.5

# %% [markdown]
# #### Compute numerical parameters

# %%
μϱ = μ * ϱ  
Δt = 1e-5*μϱ/ε^2/α^2            # Time step size
println("Non-dim. time step size           : ", Δt)

# Non-dimensional Coriolis parameter
f(x) = 1 + β*x[2]

# Final time of integration
# Tf = 0.1*μϱ/ε^2  # simulation time
Tf = 0.01*μϱ/ε^2  # simulation time
# Tf = Δt           # Just one step.
println("Non-dim. final time               : ", Tf)
println("Number of steps                   : ", Tf/Δt,"\n")
# Out:
# Non-dim. time step size           : 0.09999999999999998
# Non-dim. final time               : 249.99999999999994
# Number of steps                   : 2500.0

# %% [markdown]
# ### Build and load mesh

# %%
if(false)       # Use Tom's 2D mesh generation function.
    include("meshes/mesh_ArcticBasin2D.jl")
    mesh_name = "ArcticBasin2D"
    dim = 2
    hh = 2e-2   # Sets mesh spacing
    H, dH, R, r = generate_arctic_basin2D( hh, α; show_gui=false, savefile=mesh_name, DEBUG=false)
elseif(false)   # Use Tom's 3D mesh generation function.
                # This option takes a while to run (like an hour on my MacBook), and it gives very similar results to the 2D case.
    include("meshes/mesh_ArcticBasin3D.jl")
    mesh_name = "ArcticBasin3D"
    dim = 3
    hh = 8e-2   # Sets mesh spacing
    H, dH, R, r = generate_arctic_basin3D( hh, α; show_gui=false, savefile=mesh_name, DEBUG=false)
elseif(true)   # Use Henry's original 2D parabolic domain and mesh, modified with Tom's tags in the new spaces.jl file in nuPGCM/src.
    dim = 2
    hh = 1e-2   # Sets mesh spacing
    include("meshes/mesh_bowl2D.jl")
    mesh_name = @sprintf("bowl2D_%e_%e", hh, α)
elseif(false)   # Use Henry's original 3D parabolic domain and mesh, modified with Tom's tags in the new spaces.jl file in nuPGCM/src.
                # This option takes a while to run, and it gives very similar results to the 2D case.
    dim = 3
    hh = 8e-2   # Sets mesh spacing
    include("meshes/mesh_bowl3D.jl")
    mesh_name = @sprintf("bowl%dD_%e_%e", dim, hh, α)
end # if
@info "Loading mesh from file: " mesh_name
mesh = Mesh(joinpath(@__DIR__, "meshes/$mesh_name.msh")) ;
# Out:
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Nurb)
# Info    : [ 60%] Meshing curve 2 (Line)
# Info    : Done meshing 1D (Wall 0.0058535s, CPU 0.005829s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.114494s, CPU 0.113933s)
# Info    : 7956 nodes 15911 elements
# Info    : Writing '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/meshes/bowl2D_1.000000e-02_5.000000e-01.msh'...
# Info    : Done writing '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/meshes/bowl2D_1.000000e-02_5.000000e-01.msh'
# Info    : Reading '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/meshes/bowl2D_1.000000e-02_5.000000e-01.msh'...
# Info    : 6 entities
# Info    : 7955 nodes
# Info    : 15910 elements
# Info    : Done reading '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/meshes/bowl2D_1.000000e-02_5.000000e-01.msh'
# ┌ Info: Loading mesh from file:
# │   mesh_name = bowl2D_1.000000e-02_5.000000e-01
# └ @ Main /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X25sZmlsZQ==.jl:26
# ┌ Info: Boundary labels:
# │   label_names = ["coastline", "Bottom", "Surface", "interior"]
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/meshes.jl:19

# %% [markdown]
# #### Specify viscosity, diffusivity, and build `params` variable.

# %%
@warn "Make sure the mesh geometry is consistent with the depth(x) definition (see domain_depth() function in meshes/mesh_ArcticBasin3D.jl)."
# Non-dimensional diffusivity (enhanced at the bottom). See Peterson & Callies (2025) eq. (17)
mixing_depth = 0.1*α  # Depth over which diffusivity increases near the bottom
@info "Mixing depth (non-dimensional): " mixing_depth
κ(x) = 1e-2 + exp(-(x[3] + depth(x))/mixing_depth) ;
ν(x) = 1  # viscosity
params = Parameters(ε, α, μϱ, N²/(N² * α), Δt) ;       # Non-dimensional parameters, including N²/N² for consistency with nuPGCM, which is entirely non-dimensional.
# Out:
# ┌ Warning: Make sure the mesh geometry is consistent with the depth(x) definition (see domain_depth() function in meshes/mesh_ArcticBasin3D.jl).
# └ @ Main /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X30sZmlsZQ==.jl:1
# ┌ Info: Mixing depth (non-dimensional):
# │   mixing_depth = 0.05
# └ @ Main /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X30sZmlsZQ==.jl:4

# %% [markdown]
# ### Build system
#
#
#
# #### FE spaces

# %%
spaces = Spaces(mesh, b₀)
fe_data = FEData(mesh, spaces)
@info "DOFs: $(fe_data.dofs.nu + fe_data.dofs.nv + fe_data.dofs.nw + fe_data.dofs.np)"
# Out:
# ┌ Info: DOFs: 100339
# └ @ Main /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X32sZmlsZQ==.jl:3

# %% [markdown]
# #### Build inversion matrices if necessary: `A_inversion`, `B_inversion`
#
# To be sure, delete the saved `.jld2` files. Sometimes the file exists, but for a different parameter set, which leads to inconsistencies and errors.

# %%
if !isdir(joinpath(@__DIR__, "matrices"))
    @info "Creating matrices directory"
    mkdir(joinpath(@__DIR__, "matrices"))
end
A_inversion_fname = joinpath(@__DIR__, @sprintf("matrices/A_inversion_%sD_%e_%e_%e_%e_%e.jld2", dim, hh, ε, α, f₀, β))

if force_build_inversion
    @warn "You set `force_build_inversion` to `true`, building matrices..."
    A_inversion, B_inversion, b_inversion = build_inversion_matrices(fe_data, params, f, ν, τˣ, τʸ; A_inversion_ofile=A_inversion_fname)
elseif !isfile(A_inversion_fname)
    @warn "A_inversion file not found, generating..."
    A_inversion, B_inversion, b_inversion = build_inversion_matrices(fe_data, params, f, ν, τˣ, τʸ; A_inversion_ofile=A_inversion_fname)
else
    file = jldopen(A_inversion_fname, "r")
    A_inversion = file["A_inversion"]
    close(file)
    B_inversion = nuPGCM.build_B_inversion(fe_data, params)
    b_inversion = nuPGCM.build_b_inversion(fe_data, params, τˣ, τʸ)
end
nothing
# Out:
# ┌ Warning: You set `force_build_inversion` to `true`, building matrices...
# └ @ Main /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X34sZmlsZQ==.jl:8
# build A_inversion: 10.629590 seconds (20.84 M allocations: 1.127 GiB, 1.00% gc time, 94.96% compilation time)
# ┌ Info: A_inversion saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/matrices/A_inversion_2D_1.000000e-02_1.000000e-01_5.000000e-01_2.000000e-04_0.000000e+00.jld2' (0.043 GB)
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/matrices.jl:83

# %% [markdown]
# #### Re-order dofs

# %%
A_inversion = A_inversion[fe_data.dofs.p_inversion, fe_data.dofs.p_inversion]
B_inversion = B_inversion[fe_data.dofs.p_inversion, :]
b_inversion = b_inversion[fe_data.dofs.p_inversion] ;

# %% [markdown]
# #### Preconditioner `P_inversion`

# %%
if typeof(arch) == CPU
    @time "lu(A_inversion)" P_inversion = lu(A_inversion)
else
    P_inversion = Diagonal(on_architecture(arch, 1/hh^dim*ones(size(A_inversion, 1))))
end
nothing
# Out:
# lu(A_inversion): 0.966004 seconds (526.37 k allocations: 672.417 MiB, 1.41% gc time, 9.05% compilation time)

# %% [markdown]
# #### Move matrices to architecture

# %%
A_inversion = on_architecture(arch, A_inversion)
B_inversion = on_architecture(arch, B_inversion)
b_inversion = on_architecture(arch, b_inversion) ;

# %% [markdown]
# #### Setup inversion toolkit `inversion_toolkilt`

# %%
inversion_toolkit = InversionToolkit(A_inversion, P_inversion, B_inversion, b_inversion; atol=1e-6, rtol=1e-6) ;

# %% [markdown]
# #### Build evolution matrices `A_adv`, `A_diff`, `B_diff`, `b_diff` and test against saved matrices

# %%
A_adv, A_diff, B_diff, b_diff = build_evolution_system(fe_data, params, κ;
                                    force_build=force_build_evolution,
                                    filename=joinpath(@__DIR__, "matrices/evolution_$mesh_name.jld2")) ;
# Out:
# ┌ Warning: `force_build` set to `true`, building evolution system...
# │   filename = /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/matrices/evolution_bowl2D_1.000000e-02_5.000000e-01.jld2
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/matrices.jl:160
# ┌ Info: Evolution system saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/matrices/evolution_bowl2D_1.000000e-02_5.000000e-01.jld2' (0.018 GB)
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/matrices.jl:195

# %% [markdown]
# #### Re-order dofs

# %%
A_adv  =  A_adv[fe_data.dofs.p_b, fe_data.dofs.p_b]
A_diff = A_diff[fe_data.dofs.p_b, fe_data.dofs.p_b]
B_diff = B_diff[fe_data.dofs.p_b, :]
b_diff = b_diff[fe_data.dofs.p_b] ;

# %% [markdown]
# #### Preconditioners `P_diff` and `P_adv`

# %%
if typeof(arch) == CPU 
    P_diff = lu(A_diff)
    P_adv  = lu(A_adv)
else
    P_diff = Diagonal(on_architecture(arch, Vector(1 ./ diag(A_diff))))
    P_adv  = Diagonal(on_architecture(arch, Vector(1 ./ diag(A_adv))))
end
nothing

# %% [markdown]
# #### Move to architecture

# %%
A_adv  = on_architecture(arch, A_adv)
A_diff = on_architecture(arch, A_diff)
B_diff = on_architecture(arch, B_diff)
b_diff = on_architecture(arch, b_diff) ;

# %% [markdown]
# #### Setup evolution toolkit `evolution_toolkit`

# %%
evolution_toolkit = EvolutionToolkit(A_adv, P_adv, A_diff, P_diff, B_diff, b_diff) ;

# %% [markdown]
# #### Put it all together in the `model` struct

# %%
model = rest_state_model(arch, params, fe_data, inversion_toolkit, evolution_toolkit) ;

# %% [markdown]
# #### Set initial buoyancy

# %%
set_b!(model, x->b₀(x))
invert!(model) # sync flow with initial condition
save_vtk(model, ofile=@sprintf("%s/data/state_%016d.vtu", out_dir, 0))
# Out:
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000000.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32

# %% [markdown]
# ### Solve

# %%
n_steps = Int(round(Tf / Δt))
n_save = n_steps ÷ 100
@time run!(model; n_steps=n_steps, n_save=n_save, n_plot=n_steps)
println("Done.")
# Out:
# ┌ Info: Beginning integration with
# │   n_steps = 2500
# │   i_step = 1
# │   n_save = 25
# │   n_plot = Inf
# │   n_info = 25
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:78
# ┌ Info: t = 2.500000 (i = 25/2500, Δt = 0.100000)
# │ time elapsed: 00:00:06
# │ estimated time remaining: 00:09:38
# │ |u|ₘₐₓ = 5.0e-02, -4.5e-02 ≤ b ≤ 7.2e-02
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000025.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000025.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 5.000000 (i = 50/2500, Δt = 0.100000)
# │ time elapsed: 00:00:09
# │ estimated time remaining: 00:07:37
# │ |u|ₘₐₓ = 2.7e-02, -4.3e-02 ≤ b ≤ 7.6e-02
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000050.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000050.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 7.500000 (i = 75/2500, Δt = 0.100000)
# │ time elapsed: 00:00:13
# │ estimated time remaining: 00:06:45
# │ |u|ₘₐₓ = 1.7e-02, -4.2e-02 ≤ b ≤ 7.8e-02
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000075.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000075.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 10.000000 (i = 100/2500, Δt = 0.100000)
# │ time elapsed: 00:00:16
# │ estimated time remaining: 00:06:14
# │ |u|ₘₐₓ = 1.1e-02, -4.1e-02 ≤ b ≤ 8.0e-02
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000100.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000100.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 12.500000 (i = 125/2500, Δt = 0.100000)
# │ time elapsed: 00:00:19
# │ estimated time remaining: 00:05:56
# │ |u|ₘₐₓ = 8.2e-03, -3.9e-02 ≤ b ≤ 8.0e-02
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000125.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000125.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 15.000000 (i = 150/2500, Δt = 0.100000)
# │ time elapsed: 00:00:22
# │ estimated time remaining: 00:05:42
# │ |u|ₘₐₓ = 6.2e-03, -3.8e-02 ≤ b ≤ 8.0e-02
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000150.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000150.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 17.500000 (i = 175/2500, Δt = 0.100000)
# │ time elapsed: 00:00:25
# │ estimated time remaining: 00:05:31
# │ |u|ₘₐₓ = 4.9e-03, -3.7e-02 ≤ b ≤ 8.0e-02
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000175.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000175.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 20.000000 (i = 200/2500, Δt = 0.100000)
# │ time elapsed: 00:00:28
# │ estimated time remaining: 00:05:21
# │ |u|ₘₐₓ = 4.0e-03, -3.5e-02 ≤ b ≤ 8.0e-02
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000200.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000200.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 22.500000 (i = 225/2500, Δt = 0.100000)
# │ time elapsed: 00:00:31
# │ estimated time remaining: 00:05:12
# │ |u|ₘₐₓ = 3.4e-03, -3.5e-02 ≤ b ≤ 8.0e-02
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000225.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000225.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 25.000000 (i = 250/2500, Δt = 0.100000)
# │ time elapsed: 00:00:34
# │ estimated time remaining: 00:05:05
# │ |u|ₘₐₓ = 2.9e-03, -3.5e-02 ≤ b ≤ 7.9e-02
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000250.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000250.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 27.500000 (i = 275/2500, Δt = 0.100000)
# │ time elapsed: 00:00:37
# │ estimated time remaining: 00:04:59
# │ |u|ₘₐₓ = 2.6e-03, -3.5e-02 ≤ b ≤ 7.9e-02
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000275.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000275.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 30.000000 (i = 300/2500, Δt = 0.100000)
# │ time elapsed: 00:00:40
# │ estimated time remaining: 00:04:53
# │ |u|ₘₐₓ = 2.3e-03, -3.5e-02 ≤ b ≤ 7.8e-02
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000300.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000300.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 32.500000 (i = 325/2500, Δt = 0.100000)
# │ time elapsed: 00:00:43
# │ estimated time remaining: 00:04:48
# │ |u|ₘₐₓ = 2.1e-03, -3.5e-02 ≤ b ≤ 7.8e-02
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000325.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000325.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 35.000000 (i = 350/2500, Δt = 0.100000)
# │ time elapsed: 00:00:46
# │ estimated time remaining: 00:04:42
# │ |u|ₘₐₓ = 2.0e-03, -3.5e-02 ≤ b ≤ 7.8e-02
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000350.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000350.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 37.500000 (i = 375/2500, Δt = 0.100000)
# │ time elapsed: 00:00:49
# │ estimated time remaining: 00:04:37
# │ |u|ₘₐₓ = 2.0e-03, -3.5e-02 ≤ b ≤ 7.8e-02
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000375.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000375.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 40.000000 (i = 400/2500, Δt = 0.100000)
# │ time elapsed: 00:00:52
# │ estimated time remaining: 00:04:33
# │ |u|ₘₐₓ = 2.0e-03, -3.5e-02 ≤ b ≤ 7.7e-02
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000400.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000400.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 42.500000 (i = 425/2500, Δt = 0.100000)
# │ time elapsed: 00:00:55
# │ estimated time remaining: 00:04:28
# │ |u|ₘₐₓ = 2.0e-03, -3.5e-02 ≤ b ≤ 7.7e-02
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000425.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000425.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 45.000000 (i = 450/2500, Δt = 0.100000)
# │ time elapsed: 00:00:58
# │ estimated time remaining: 00:04:24
# │ |u|ₘₐₓ = 2.0e-03, -3.5e-02 ≤ b ≤ 7.7e-02
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000450.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000450.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 47.500000 (i = 475/2500, Δt = 0.100000)
# │ time elapsed: 00:01:01
# │ estimated time remaining: 00:04:19
# │ |u|ₘₐₓ = 1.9e-03, -3.5e-02 ≤ b ≤ 7.7e-02
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000475.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000475.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 50.000000 (i = 500/2500, Δt = 0.100000)
# │ time elapsed: 00:01:04
# │ estimated time remaining: 00:04:15
# │ |u|ₘₐₓ = 1.9e-03, -3.5e-02 ≤ b ≤ 7.7e-02
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000500.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000500.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 52.500000 (i = 525/2500, Δt = 0.100000)
# │ time elapsed: 00:01:07
# │ estimated time remaining: 00:04:12
# │ |u|ₘₐₓ = 1.9e-03, -3.5e-02 ≤ b ≤ 7.7e-02
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000525.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000525.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 55.000000 (i = 550/2500, Δt = 0.100000)
# │ time elapsed: 00:01:10
# │ estimated time remaining: 00:04:08
# │ |u|ₘₐₓ = 1.9e-03, -3.5e-02 ≤ b ≤ 7.7e-02
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000550.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000550.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 57.500000 (i = 575/2500, Δt = 0.100000)
# │ time elapsed: 00:01:13
# │ estimated time remaining: 00:04:04
# │ |u|ₘₐₓ = 1.9e-03, -3.5e-02 ≤ b ≤ 7.9e-02
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000575.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000575.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 60.000000 (i = 600/2500, Δt = 0.100000)
# │ time elapsed: 00:01:16
# │ estimated time remaining: 00:04:00
# │ |u|ₘₐₓ = 1.9e-03, -3.5e-02 ≤ b ≤ 8.1e-02
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000600.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000600.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 62.500000 (i = 625/2500, Δt = 0.100000)
# │ time elapsed: 00:01:19
# │ estimated time remaining: 00:03:56
# │ |u|ₘₐₓ = 1.9e-03, -3.5e-02 ≤ b ≤ 8.4e-02
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000625.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000625.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 65.000000 (i = 650/2500, Δt = 0.100000)
# │ time elapsed: 00:01:22
# │ estimated time remaining: 00:03:53
# │ |u|ₘₐₓ = 1.9e-03, -3.5e-02 ≤ b ≤ 8.6e-02
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000650.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000650.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 67.500000 (i = 675/2500, Δt = 0.100000)
# │ time elapsed: 00:01:25
# │ estimated time remaining: 00:03:49
# │ |u|ₘₐₓ = 1.9e-03, -3.5e-02 ≤ b ≤ 8.8e-02
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000675.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000675.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 70.000000 (i = 700/2500, Δt = 0.100000)
# │ time elapsed: 00:01:28
# │ estimated time remaining: 00:03:46
# │ |u|ₘₐₓ = 1.9e-03, -3.5e-02 ≤ b ≤ 9.0e-02
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000700.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000700.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 72.500000 (i = 725/2500, Δt = 0.100000)
# │ time elapsed: 00:01:31
# │ estimated time remaining: 00:03:42
# │ |u|ₘₐₓ = 1.9e-03, -3.5e-02 ≤ b ≤ 9.2e-02
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000725.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000725.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 75.000000 (i = 750/2500, Δt = 0.100000)
# │ time elapsed: 00:01:34
# │ estimated time remaining: 00:03:39
# │ |u|ₘₐₓ = 1.9e-03, -3.5e-02 ≤ b ≤ 9.4e-02
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000750.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000750.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 77.500000 (i = 775/2500, Δt = 0.100000)
# │ time elapsed: 00:01:37
# │ estimated time remaining: 00:03:35
# │ |u|ₘₐₓ = 1.9e-03, -3.5e-02 ≤ b ≤ 9.6e-02
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000775.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000775.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 80.000000 (i = 800/2500, Δt = 0.100000)
# │ time elapsed: 00:01:40
# │ estimated time remaining: 00:03:32
# │ |u|ₘₐₓ = 1.9e-03, -3.6e-02 ≤ b ≤ 9.8e-02
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000800.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000800.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 82.500000 (i = 825/2500, Δt = 0.100000)
# │ time elapsed: 00:01:43
# │ estimated time remaining: 00:03:28
# │ |u|ₘₐₓ = 1.9e-03, -3.6e-02 ≤ b ≤ 1.0e-01
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000825.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000825.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 85.000000 (i = 850/2500, Δt = 0.100000)
# │ time elapsed: 00:01:46
# │ estimated time remaining: 00:03:25
# │ |u|ₘₐₓ = 1.9e-03, -3.6e-02 ≤ b ≤ 1.0e-01
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000850.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000850.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 87.500000 (i = 875/2500, Δt = 0.100000)
# │ time elapsed: 00:01:49
# │ estimated time remaining: 00:03:22
# │ |u|ₘₐₓ = 1.9e-03, -3.6e-02 ≤ b ≤ 1.0e-01
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000875.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000875.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 90.000000 (i = 900/2500, Δt = 0.100000)
# │ time elapsed: 00:01:52
# │ estimated time remaining: 00:03:18
# │ |u|ₘₐₓ = 1.9e-03, -3.6e-02 ≤ b ≤ 1.1e-01
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000900.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000900.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 92.500000 (i = 925/2500, Δt = 0.100000)
# │ time elapsed: 00:01:55
# │ estimated time remaining: 00:03:15
# │ |u|ₘₐₓ = 1.8e-03, -3.6e-02 ≤ b ≤ 1.1e-01
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000925.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000925.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 95.000000 (i = 950/2500, Δt = 0.100000)
# │ time elapsed: 00:01:58
# │ estimated time remaining: 00:03:12
# │ |u|ₘₐₓ = 1.8e-03, -3.6e-02 ≤ b ≤ 1.1e-01
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000950.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000950.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 97.500000 (i = 975/2500, Δt = 0.100000)
# │ time elapsed: 00:02:00
# │ estimated time remaining: 00:03:08
# │ |u|ₘₐₓ = 1.8e-03, -3.6e-02 ≤ b ≤ 1.1e-01
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000975.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000000975.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 100.000000 (i = 1000/2500, Δt = 0.100000)
# │ time elapsed: 00:02:03
# │ estimated time remaining: 00:03:05
# │ |u|ₘₐₓ = 1.8e-03, -3.6e-02 ≤ b ≤ 1.1e-01
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000001000.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000001000.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 102.500000 (i = 1025/2500, Δt = 0.100000)
# │ time elapsed: 00:02:06
# │ estimated time remaining: 00:03:02
# │ |u|ₘₐₓ = 1.8e-03, -3.6e-02 ≤ b ≤ 1.1e-01
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000001025.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000001025.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 105.000000 (i = 1050/2500, Δt = 0.100000)
# │ time elapsed: 00:02:09
# │ estimated time remaining: 00:02:59
# │ |u|ₘₐₓ = 1.8e-03, -3.6e-02 ≤ b ≤ 1.2e-01
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000001050.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000001050.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 107.500000 (i = 1075/2500, Δt = 0.100000)
# │ time elapsed: 00:02:12
# │ estimated time remaining: 00:02:55
# │ |u|ₘₐₓ = 1.8e-03, -3.6e-02 ≤ b ≤ 1.2e-01
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000001075.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000001075.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 110.000000 (i = 1100/2500, Δt = 0.100000)
# │ time elapsed: 00:02:15
# │ estimated time remaining: 00:02:52
# │ |u|ₘₐₓ = 1.8e-03, -3.6e-02 ≤ b ≤ 1.2e-01
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000001100.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000001100.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 112.500000 (i = 1125/2500, Δt = 0.100000)
# │ time elapsed: 00:02:18
# │ estimated time remaining: 00:02:49
# │ |u|ₘₐₓ = 1.8e-03, -3.6e-02 ≤ b ≤ 1.2e-01
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000001125.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000001125.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 115.000000 (i = 1150/2500, Δt = 0.100000)
# │ time elapsed: 00:02:21
# │ estimated time remaining: 00:02:46
# │ |u|ₘₐₓ = 1.8e-03, -3.6e-02 ≤ b ≤ 1.2e-01
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000001150.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000001150.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 117.500000 (i = 1175/2500, Δt = 0.100000)
# │ time elapsed: 00:02:24
# │ estimated time remaining: 00:02:43
# │ |u|ₘₐₓ = 1.8e-03, -3.6e-02 ≤ b ≤ 1.2e-01
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ...
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000002125.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 215.000000 (i = 2150/2500, Δt = 0.100000)
# │ time elapsed: 00:04:22
# │ estimated time remaining: 00:00:43
# │ |u|ₘₐₓ = 1.7e-03, -3.6e-02 ≤ b ≤ 1.7e-01
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000002150.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000002150.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 217.500000 (i = 2175/2500, Δt = 0.100000)
# │ time elapsed: 00:04:25
# │ estimated time remaining: 00:00:40
# │ |u|ₘₐₓ = 1.7e-03, -3.6e-02 ≤ b ≤ 1.7e-01
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000002175.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000002175.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 220.000000 (i = 2200/2500, Δt = 0.100000)
# │ time elapsed: 00:04:28
# │ estimated time remaining: 00:00:37
# │ |u|ₘₐₓ = 1.7e-03, -3.6e-02 ≤ b ≤ 1.7e-01
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000002200.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000002200.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 222.500000 (i = 2225/2500, Δt = 0.100000)
# │ time elapsed: 00:04:31
# │ estimated time remaining: 00:00:33
# │ |u|ₘₐₓ = 1.7e-03, -3.6e-02 ≤ b ≤ 1.7e-01
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000002225.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000002225.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 225.000000 (i = 2250/2500, Δt = 0.100000)
# │ time elapsed: 00:04:34
# │ estimated time remaining: 00:00:30
# │ |u|ₘₐₓ = 1.7e-03, -3.6e-02 ≤ b ≤ 1.7e-01
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000002250.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000002250.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 227.500000 (i = 2275/2500, Δt = 0.100000)
# │ time elapsed: 00:04:37
# │ estimated time remaining: 00:00:27
# │ |u|ₘₐₓ = 1.7e-03, -3.7e-02 ≤ b ≤ 1.7e-01
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000002275.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000002275.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 230.000000 (i = 2300/2500, Δt = 0.100000)
# │ time elapsed: 00:04:40
# │ estimated time remaining: 00:00:24
# │ |u|ₘₐₓ = 1.7e-03, -3.7e-02 ≤ b ≤ 1.7e-01
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000002300.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000002300.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 232.500000 (i = 2325/2500, Δt = 0.100000)
# │ time elapsed: 00:04:43
# │ estimated time remaining: 00:00:21
# │ |u|ₘₐₓ = 1.7e-03, -3.7e-02 ≤ b ≤ 1.7e-01
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000002325.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000002325.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 235.000000 (i = 2350/2500, Δt = 0.100000)
# │ time elapsed: 00:04:46
# │ estimated time remaining: 00:00:18
# │ |u|ₘₐₓ = 1.7e-03, -3.7e-02 ≤ b ≤ 1.8e-01
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000002350.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000002350.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 237.500000 (i = 2375/2500, Δt = 0.100000)
# │ time elapsed: 00:04:49
# │ estimated time remaining: 00:00:15
# │ |u|ₘₐₓ = 1.7e-03, -3.7e-02 ≤ b ≤ 1.8e-01
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000002375.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000002375.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 240.000000 (i = 2400/2500, Δt = 0.100000)
# │ time elapsed: 00:04:52
# │ estimated time remaining: 00:00:12
# │ |u|ₘₐₓ = 1.7e-03, -3.7e-02 ≤ b ≤ 1.8e-01
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000002400.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000002400.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 242.500000 (i = 2425/2500, Δt = 0.100000)
# │ time elapsed: 00:04:55
# │ estimated time remaining: 00:00:09
# │ |u|ₘₐₓ = 1.7e-03, -3.7e-02 ≤ b ≤ 1.8e-01
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000002425.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000002425.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 245.000000 (i = 2450/2500, Δt = 0.100000)
# │ time elapsed: 00:04:58
# │ estimated time remaining: 00:00:06
# │ |u|ₘₐₓ = 1.7e-03, -3.7e-02 ≤ b ≤ 1.8e-01
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000002450.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000002450.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 247.500000 (i = 2475/2500, Δt = 0.100000)
# │ time elapsed: 00:05:01
# │ estimated time remaining: 00:00:03
# │ |u|ₘₐₓ = 1.7e-03, -3.7e-02 ≤ b ≤ 1.8e-01
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000002475.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000002475.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
# ┌ Info: t = 250.000000 (i = 2500/2500, Δt = 0.100000)
# │ time elapsed: 00:05:04
# │ estimated time remaining: 00:00:00
# │ |u|ₘₐₓ = 1.7e-03, -3.7e-02 ≤ b ≤ 1.8e-01
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/model.jl:100
# 305.055702 seconds (1.07 G allocations: 113.466 GiB, 1.53% gc time, 1.45% compilation time: 2% of which was recompilation)
# Done.
# ┌ Info: Model state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000002500.jld2'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:5
# ┌ Info: VTK state saved to '/Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM//data/state_0000000000002500.vtu'
# └ @ nuPGCM /Users/twnh/Library/CloudStorage/OneDrive-JohnsHopkins/Documents/Meetings/ArcticOceanDynamics_Nov25/ArcticBoundaryCurrentModel/nuPGCM/src/IO.jl:32
